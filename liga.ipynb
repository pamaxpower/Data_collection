# %%
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
from pprint import pprint

# %%
ua = UserAgent()
ua.safari
# Out:
# 'Mozilla/5.0 (iPad; CPU OS 17_0_2 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/17.0 Mobile/15E148 Safari/604.1'

# %%
url = 'https://tt.sport-liga.pro'

headers = {
    "User-Agent": ua.safari}

params = {
    'date_from': "2024-04-26",
    'date_to': "2024-04-26"
}

response = requests.get(url+'/tours', headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="h-100" lang="ru">
# <head>
# <base href="/"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="настольный теннис, турниры по настольному теннису" name="keywords"/>
# <meta content="Лига ПРО" name="description"/>
# <meta content="1872bc857723a1a1" name="yandex-verification"/>
# <title>Страница не найдена | Лига ПРО - турниры по настольному теннису</title>
# <link href="//fonts.googleapis.com/css?family=Roboto:400,500,700,400italic|Material+Icons" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css" integrity="sha384-ggOyR0iXCbMQv3Xipma34MD+dH/1fQ784/j6cY/iJTQUOhcWr7x9JvoRxT2MZw1T" rel="stylesheet"/>
# <link href="plugins/colorbox/colorbox.css" rel="stylesheet" type="text/css"/>
# <link href="plugins/jquery/jquery-ui/jquery-ui-1.10.4.custom.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.datatables.net/v/bs4/dt-1.10.22/b-1.6.4/b-html5-1.6.4/fc-3.3.1/kt-2.5.3/r-2.2.6/rg-1.1.2/rr-1.2.7/sc-2.0.3/sb-1.0.0/sp-1.2.0/sl-1.3.1/datatables.min.css" rel="stylesheet" type="text/css">
# <!--<link href="css/base.css" rel="stylesheet">-->
# <link href="css/fonts.css" rel="stylesheet"/>
# <link href="css/styles.css?1713820039" rel="stylesheet"/>
# <link href="css/media.css" rel="stylesheet"/>
# <link href="images/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <script crossorigin="anonymous" integrity="sha256-BbhdlvQf/xTY9gja0Dq3HiwQF8LaCRTXxZKRutelT44=" src="https://code.jquery.com/jquery-2.2.4.min.js"></script>
# <script src="plugins/jquery/jquery-ui/jquery-ui-1.10.4.custom.min.js" type="text/javascript"></script>
# <script src="plugins/colorbox/jquery.colorbox-min.js" type="text/javascript"></script>
# <script src="js/utils.js" type="text/javascript"></script>
# <script src="js/main.js" type="text/javascript"></script>
# <!--<script type="text/javascript" src="js/online.js"></script>-->
# <script src="https://www.google.com/recaptcha/api.js"></script>
# </link></link></head>
# <body onload="">
# <div class="alert alert-lp alert-dismissible mb-0 p-2 fade show border-0 text-center hidden" id="new-site-link" role="alert">
# <div class="d-flex justify-content-between align-items-center">
# <div class="flex-fill text-left">
# <button aria-label="Close" class="close-lp" data-dismiss="alert" onclick="save_session();" type="button">
# <span aria-hidden="true" style="vertical-align: text-top;">×</span>
# </button>
# </div>
# <div class="mr-3 ml-2 text-left"><strong>Новая версия сайта!</strong> <span style="display: inline-block; line-height: 18px;">Обновленный дизайн и все виды спорта сразу</span></div>
# <div class="flex-fill text-left pl-3">
# <a aria-pressed="true" class="btn btn-primary" href="//www.sport-liga.pro/" onclick="save_session();" role="button" target="_blank">Перейти</a>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#   $(document).ready(function () {
#     if (!sessionStorage.getItem("key_s")) {
#       $("#new-site-link").show();
#     } else {
#       $("#new-site-link").hide();
#     }
#   });
#
#   function save_session() {
#     let s = sessionStorage.getItem("key_s");
#     if (!s) {
#       sessionStorage.setItem("key_s", "true");
#       $("#new-site-link").hide();
#     }
#   }
#
#   function getBool(val) {
#     return !!JSON.parse(String(val).toLowerCase());
#   }
# </script>
# <style>
#     .alert-lp {
#         color: #FFFFFF;
#         background-color: #444D5A;
#         border-color: #444D5A;
#         border-radius: 0 !important;
#     }
#
#     .close-lp {
#         float: left;
#         font-size: 1.8rem;
#         font-weight: 700;
#         line-height: 1;
#         color: #fff;
#         text-shadow: none;
#         background: transparent;
#         border: 0;
#     }
# </style>
# <div aria-atomic="true" aria-live="polite" style="position: relative;">
# <div style="position: absolute; top: 50px; right: 10px; min-width: 250px; z-index: 10;">
# <div aria-atomic="true" aria-live="assertive" class="toast d-none" data-animation="true" data-autohide="false" id="new_messages_block" role="alert">
# <div class="toast-header">
# <strong class="icon-mail mr-auto"></strong>
# </div>
# <div class="toast-body">
# <a class="h6" href="messages/" id="new_messages">Новое сообщение!</a>
# </div>
# </div>
# <div aria-atomic="true" aria-live="assertive" class="toast d-none" data-animation="true" data-autohide="false" id="new_messages17_block" role="alert">
# <div class="toast-header">
# <strong class="icon-mail mr-auto"></strong>
# </div>
# <div class="toast-body">
# <a class="h6" href="forum/17" id="new_messages17">Сообщение для букмекера!!!</a>
# </div>
# </div>
# </div>
# </div>
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript">
#   (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#     m[i].l=1*new Date();
#     for (var j = 0; j < document.scripts.length; j++) {if (document.scripts[j].src === r) { return; }}
#     k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
#   (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#   ym(43621554, "init", {
#     clickmap:true,
#     trackLinks:true,
#     accurateTrackBounce:true,
#     webvisor:true,
#     trackHash:true,
#     userParams: {
#       is_have_role: getBool("false"),
#       login: "",
#       UserID: parseInt("")
#     },
#   });
# </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/43621554" style="position:absolute; left:-9999px;"/></div></noscript>
# <!-- /Yandex.Metrika counter -->
# <audio id="audio" src="upload/files/IncomingIM.mp3"></audio>
# <div class="popup-overlay"></div>
# <div class="login-popup-form">
# <div class="popup-close-btn"><span class="icon-cancel"></span></div>
# <div class="title"><h2>Вход на сайт</h2></div>
# <form action="/404.php" autocomplete="off" method="post">
# <input name="login" placeholder="Логин" type="text"/>
# <input name="password" placeholder="Пароль" type="password"/>
# <a class="bl" href="forgot/">Забыли пароль?</a>
# <input class="button" style="margin-top:10px;" type="submit" value="Войти"/>
# </form>
# </div>
# <div class="mail-2-popup-overlay"></div>
# <div class="mail-2-popup-form">
# <div class="mail-2-popup-close-btn"><span class="icon-cancel"></span></div>
# <div class="title"><h2>Отправка личного сообщения</h2></div>
# <form action="messages/" id="form-message-block" method="post">
# <input id="mail-popup-player" name="player_id" type="hidden" value=""/>
# <div class="adr">Сообщение для: <img alt="" class="userpic" id="mail-popup-img" src=""/><span id="mail-popup-span">Николай Иванов (<a class="username" href="">Brad</a>)</span></div>
# <!--<input type="text" placeholder="Кому">-->
# <textarea id="form-message-block-input" name="text" placeholder="Текст сообщения"></textarea>
# <span class="red" id="form-message-block-error"></span>
# <input class="button" type="submit" value="Отправить"/>
# </form>
# </div>
# <script>
#   $('#form-message-block').submit(e => {
#     const messageData = $('#form-message-block-input').val();
#     const commentErr = $('#form-message-block-error');
#
#     if (messageData.match(/^[а-яА-ЯёЁa-zA-Z0-9\s.,:!?\-+()@]+$/) !== null) {
#       commentErr.text('');
#     } else {
#       e.preventDefault();
#       commentErr.text('Используйте только допустимые символы: . , : ! ? _ - + ( ) @');
#     }
#   })
# </script>
# <div class="mail-3-popup-overlay"></div>
# <div class="mail-3-popup-form">
# <div class="mail-3-popup-close-btn"><span class="icon-cancel"></span></div>
# <div class="title"><h2>Редактирование сообщения</h2></div>
# <input id="mail-popup-player" name="player_id" type="hidden" value=""/>
# <textarea id="mail-3-popup-text" mes_id="" name="text" placeholder="Текст сообщения"></textarea>
# <input class="button" onclick="editMessage();" type="button" value="Сохранить"/>
# </div>
# <header>
# <div class="pos-f-t bg-dark">
# <div class="collapse" id="searchPanel">
# <div class="container">
# <div class="row">
# <div class="col-12 col-lg-6 py-3 offset-lg-3">
# <form action="/search/" class="navbar-form" method="get" role="search">
# <div class="input-group">
# <input class="form-control form-control-sm" id="search" name="s" placeholder="Поиск..." type="text" value=""/>
# <div class="input-group-btn">
# <button class="btn btn-secondary btn-sm" type="submit">Поиск</button>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="header-top">
# <div class="container">
# <div class="d-flex justify-content-between">
# <div class="text-uppercase d-none d-xl-block">
# <a class="nav-link" href="http://sport-liga.pro/" rel="nofollow" target="_blank">Лига профессиональных турниров</a>
# </div>
# <div class="text-lg-center d-none d-xl-block flex-fill" style="max-width: 640px;">
# <div class="carousel slide px-5" data-interval="false" id="links_slider">
# <div class="carousel-inner">
# <div class="carousel-item active">
# <ul class="nav justify-content-center">
# <li class="nav-item">
# <noindex><a class="nav-link" href="https://football.sport-liga.pro/" rel="nofollow" target="_blank">Футбол</a>
# </noindex>
# </li>
# <li class="nav-item">
# <noindex><a class="nav-link" href="https://tennis.sport-liga.pro/" rel="nofollow" target="_blank">Теннис</a>
# </noindex>
# </li>
# <li class="nav-item">
# <noindex><a class="nav-link" href="https://volley.sport-liga.pro/" rel="nofollow" target="_blank">Волейбол</a>
# </noindex>
# </li>
# <li class="nav-item">
# <noindex><a class="nav-link" href="https://basket.sport-liga.pro/" rel="nofollow" target="_blank">Баскетбол 3x3</a></noindex>
# </li>
# <li class="nav-item">
# <noindex><a class="nav-link" href="https://hockey.sport-liga.pro/" rel="nofollow" target="_blank">Хоккей</a>
# </noindex>
# </li>
# </ul>
# </div>
# <div class="carousel-item">
# <ul class="nav justify-content-center">
# <li class="nav-item">
# <noindex><a class="nav-link" href="https://ebasketball.sport-liga.pro/" rel="nofollow" target="_blank">Кибербаскетбол</a></noindex>
# </li>
# <li class="nav-item">
# <noindex><a class="nav-link" href="https://efootball.sport-liga.pro/" rel="nofollow" target="_blank">Киберфутбол</a></noindex>
# </li>
# <li class="nav-item">
# <noindex><a class="nav-link" href="https://ehockey.sport-liga.pro/" rel="nofollow" target="_blank">Киберхоккей</a>
# </noindex>
# </li>
# <li class="nav-item">
# <noindex><a class="nav-link" href="https://evolleyball.sport-liga.pro/" rel="nofollow" target="_blank">Киберволейбол</a></noindex>
# </li>
# <!--li class="nav-item">
#                    <noindex><a class="nav-link" href="http://pool.sport-liga.pro/" target="_blank" rel="nofollow">Бильярд</a></noindex>
#                   </li-->
# </ul>
# </div>
# </div>
# <a class="carousel-control-prev" data-slide="prev" href="#links_slider" role="button">
# <span aria-hidden="true" class="carousel-control-prev-icon"></span>
# <span class="sr-only">Previous</span>
# </a>
# <a class="carousel-control-next" data-slide="next" href="#links_slider" role="button">
# <span aria-hidden="true" class="carousel-control-next-icon"></span>
# <span class="sr-only">Next</span>
# </a>
# </div>
# </div>
# <div class="text-right">
# <ul class="nav header-top-menu">
# <li class="nav-item pr-1">
# <button aria-controls="searchPanel" aria-expanded="false" class="btn btn-link btn-sm align-baseline text-white" data-target="#searchPanel" data-toggle="collapse" type="button">
# <span class="icon-search"></span>
# </button>
# </li>
# <li class="nav-item">
# <span class="nav-link to-login cursor-pointer">Вход</span>
# </li>
# <li class="separator">|</li>
# <li class="nav-item">
# <a class="nav-link to-register" href="registration/">Регистрация</a>
# </li>
# <li class="nav-item">
# <span class="cursor-pointer nav-link" onclick="load_lang('lang','ru', 365);">RU</span>
# </li>
# <li class="separator">|</li>
# <li class="nav-item">
# <span class="cursor-pointer nav-link" onclick="load_lang('lang','en', 365);">EN</span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#     function load_lang(name, value, days) {
#       var expires;
#       if (days) {
#         var date = new Date();
#         date.setTime(date.getTime() + (days * 24 * 60 * 60 * 1000));
#         expires = "; expires=" + date.toGMTString();
#       } else {
#         expires = "";
#       }
#       document.cookie = name + "=" + value + expires + "; path=/;" + "domain=." + location.host;
#       location.reload();
#     }
#   </script>
# <style>
#       .blink {
#           animation-name: blinker;
#           animation-iteration-count: infinite;
#           animation-timing-function: cubic-bezier(1.0, 0, 0, 1.0);
#           animation-duration: 2s;
#           -webkit-animation-name: blinker;
#           -webkit-animation-iteration-count: infinite;
#           -webkit-animation-timing-function: cubic-bezier(1.0, 0, 0, 1.0);
#           -webkit-animation-duration: 2s;
#           font-size: 1.58rem;
#           line-height: 0.5;
#           vertical-align: text-top;
#       }
#
#       @keyframes blinker {
#           from {
#               opacity: 1.0;
#           }
#           to {
#               opacity: 0.0;
#           }
#       }
#
#       @-webkit-keyframes blinker {
#           from {
#               opacity: 1.0;
#           }
#           to {
#               opacity: 0.0;
#           }
#       }
#   </style>
# <div class="header-main">
# <nav class="navbar p-lg-0 p-md-0 navbar-dark navbar-expand-lg">
# <div class="container">
# <a class="navbar-brand text-left py-2 px-0 router-link-exact-active router-link-active m-0" href="/" target="_self">
# <img alt="Logo" height="54" src="images/logo.png?1713820040"/>
# </a>
# <button aria-controls="navbar" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler px-1" data-target="#navbar" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse" id="navbar">
# <div class="navbar-nav ml-auto text-uppercase text-white">
# <a class="nav-item nav-link text-white nav-font-size f8" href="tours/">ЛИГА ПРО турниры</a>
# <a class="nav-item nav-link text-white nav-font-size f8" href="toursfntr/">ФНТР</a>
# <a class="nav-item nav-link text-white nav-font-size f8" href="players/">Игроки</a>
# <a class="nav-item nav-link text-white nav-font-size f8" href="news/">Новости</a>
# <a class="nav-item nav-link text-white nav-font-size f8" href="content/11">Контакты</a>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </header>
# <div class="main-page" id="content">
# <div class="wrapper">
# <div class="container">
# <div class="row"><div class="col-12 col-sm-12 col-md-12 col-lg-9">
# <div class="main-column">
# <div class="breadcrumbs">
# <ul>
# <li><a href="/">Главная</a></li>
# <li class="active">Страница не найдена</li>
# </ul>
# </div>
# <div class="node-page page">
# <div class="node">
# <div class="title"><h1>Страница не найдена</h1></div>
# <div class="node-content item">
#      ...
#     </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-sm-12 col-md-12 col-lg-3" id="right">
# <div class="right-sidebar sidebar">
# <div class="results block wrapper">
# <div class="title" style="text-align:right;">
# <div class="pattern"></div>
# <h2 style="padding:0px 0px 0px 10px;"><a href="tours/">Прошедшие турниры</a></h2>
# </div>
# <div class="items">
# <div class="item" style="text-align:right;">
# <a href="tours/33849">
# <div class="date">
# <span class="day">25 Апр</span>
# <span class="time">чтв</span>
# <span class="day">12:00</span>
# </div>
# <a href="tours/33849"><div class="title"><h3>Турнир А15. лига 500-550. Минск <small>(Зал A15)</small></h3></div></a>
# </a>
# <div class="about">
# <a class="all-page text-body name medal icon-gold" href="players/6979">Романенко Дмитрий</a>
# <a class="userpic-xs" href="players/6979"><img alt="Романенко Дмитрий" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/mini_6979.jpg');"/></a>
# </div>
# </div>
# <div class="item" style="text-align:right;">
# <a href="tours/33853">
# <div class="date">
# <span class="day">25 Апр</span>
# <span class="time">чтв</span>
# <span class="day">12:00</span>
# </div>
# <a href="tours/33853"><div class="title"><h3>Турнир А3. лига 550-600 <small>(Зал A3)</small></h3></div></a>
# </a>
# <div class="about">
# <a class="all-page text-body name medal icon-gold" href="players/2496">Лыфенко Никита</a>
# <a class="userpic-xs" href="players/2496"><img alt="Лыфенко Никита" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/mini_2496.jpg');"/></a>
# </div>
# </div>
# <div class="item" style="text-align:right;">
# <a href="tours/33857">
# <div class="date">
# <span class="day">25 Апр</span>
# <span class="time">чтв</span>
# <span class="day">11:45</span>
# </div>
# <a href="tours/33857"><div class="title"><h3>Турнир А4. лига 450-500 <small>(Зал A4)</small></h3></div></a>
# </a>
# <div class="about">
# <a class="all-page text-body name medal icon-gold" href="players/6363">Мамека Максим</a>
# <a class="userpic-xs" href="players/6363"><img alt="Мамека Максим" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/mini_6363.jpg');"/></a>
# </div>
# </div>
# <div class="item" style="text-align:right;">
# <a href="tours/33867">
# <div class="date">
# <span class="day">25 Апр</span>
# <span class="time">чтв</span>
# <span class="day">11:45</span>
# </div>
# <a href="tours/33867"><div class="title"><h3>Турнир А6. лига 700-800 <small>(Зал A6)</small></h3></div></a>
# </a>
# <div class="about">
# <a class="all-page text-body name medal icon-gold" href="players/1443">Туницын Дмитрий</a>
# <a class="userpic-xs" href="players/1443"><img alt="Туницын Дмитрий" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/mini_1443.jpg');"/></a>
# </div>
# </div>
# <div class="item" style="text-align:right;">
# <a href="tours/33862">
# <div class="date">
# <span class="day">25 Апр</span>
# <span class="time">чтв</span>
# <span class="day">11:30</span>
# </div>
# <a href="tours/33862"><div class="title"><h3>Турнир А5. лига 500-550 <small>(Зал A5)</small></h3></div></a>
# </a>
# <div class="about">
# <a class="all-page text-body name medal icon-gold" href="players/4585">Калинников Геннадий</a>
# <a class="userpic-xs" href="players/4585"><img alt="Калинников Геннадий" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/mini_4585.jpg');"/></a>
# </div>
# </div>
# <div class="item" style="text-align:right;">
# <a href="tours/33848">
# <div class="date">
# <span class="day">25 Апр</span>
# <span class="time">чтв</span>
# <span class="day">08:00</span>
# </div>
# <a href="tours/33848"><div class="title"><h3>Турнир А15. лига 450-500. Минск <small>(Зал A15)</small></h3></div></a>
# </a>
# <div class="about">
# <a class="all-page text-body name medal icon-gold" href="players/6800">Синявский Владимир</a>
# <a class="userpic-xs" href="players/6800"><img alt="Синявский Владимир" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/mini_6800.jpg');"/></a>
# </div>
# </div>
# <div class="item" style="text-align:right;">
# <a href="tours/33852">
# <div class="date">
# <span class="day">25 Апр</span>
# <span class="time">чтв</span>
# <span class="day">08:00</span>
# </div>
# <a href="tours/33852"><div class="title"><h3>Турнир А3. лига 300-350 <small>(Зал A3)</small></h3></div></a>
# </a>
# <div class="about">
# <a class="all-page text-body name medal icon-gold" href="players/7189">Мошников Олег</a>
# <a class="userpic-xs" href="players/7189"><img alt="Мошников Олег" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/mini_7189.jpg');"/></a>
# </div>
# </div>
# <div class="item" style="text-align:right;">
# <a href="tours/33856">
# <div class="date">
# <span class="day">25 Апр</span>
# <span class="time">чтв</span>
# <span class="day">07:45</span>
# </div>
# <a href="tours/33856"><div class="title"><h3>Турнир А4. лига 600-700 <small>(Зал A4)</small></h3></div></a>
# </a>
# <div class="about">
# <a class="all-page text-body name medal icon-gold" href="players/2257">Клавденков Александр</a>
# <a class="userpic-xs" href="players/2257"><img alt="Клавденков Александр" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/mini_2257.jpg');"/></a>
# </div>
# </div>
# <div class="item" style="text-align:right;">
# <a href="tours/33866">
# <div class="date">
# <span class="day">25 Апр</span>
# <span class="time">чтв</span>
# <span class="day">07:45</span>
# </div>
# <a href="tours/33866"><div class="title"><h3>Турнир А6. лига 700-800 <small>(Зал A6)</small></h3></div></a>
# </a>
# <div class="about">
# <a class="all-page text-body name medal icon-gold" href="players/5473">Мартюхин Сергей</a>
# <a class="userpic-xs" href="players/5473"><img alt="Мартюхин Сергей" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/mini_5473.jpg');"/></a>
# </div>
# </div>
# <div class="item" style="text-align:right;">
# <a href="tours/33861">
# <div class="date">
# <span class="day">25 Апр</span>
# <span class="time">чтв</span>
# <span class="day">07:30</span>
# </div>
# <a href="tours/33861"><div class="title"><h3>Турнир А5. лига 250-300 <small>(Зал A5)</small></h3></div></a>
# </a>
# <div class="about">
# <a class="all-page text-body name medal icon-gold" href="players/8771">Плищенко Сергей</a>
# <a class="userpic-xs" href="players/8771"><img alt="Плищенко Сергей" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/mini_8771.jpg');"/></a>
# </div>
# </div>
# </div>
# <div class="link"><a class="icon-arws" href="tours/">все результаты</a></div>
# </div>
# <div class="banner block" style="text-align:center; height:auto; background:none;"></div>
# <div class="banner block" style="text-align:center; height:auto; background:none;"></div>
# <div class="banner block" style="text-align:center; height:auto; background:none;"></div>
# <div class="banner block" style="text-align:center; height:auto; background:none;"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <footer>
# <div class="wrapper">
# <div class="container">
# <div class="row">
# <div class="col-12 col-md-6 col-lg-4 mb-4 mb-md-0">
# <div class="logo-footer" onclick="window.location='/';" style="background: url('../images/logo-footer.png?1713820040') no-repeat;"></div>
# <div class="desc">
#         Профессиональные турниры по настольному теннису.<br/>Календарь турниров, рейтинг, статистика и многое другое...
#        </div>
# </div>
# <div class="col-6 col-md-3 col-lg-2 mb-4">
# <ul class="footer-menu">
# <li class="title"><a href="/">Главная</a></li>
# <li class="link"><a href="tours/">ЛИГА ПРО турниры</a></li>
# <li class="link"><a href="toursfntr/">ФНТР</a></li>
# <li class="link"><a href="players/">Игроки</a></li>
# <li class="link"><a href="news/">Новости</a></li>
# <li class="link"><a href="content/11">Контакты</a></li>
# </ul>
# </div>
# <div class="col-6 col-md-3 col-lg-2">
# <ul class="footer-menu">
# <li class="title"><a href="tours/#gomonth">Календарь</a></li>
# </ul>
# <ul class="footer-menu mb-2">
# <li class="title">Игроки</li>
# <li class="link"><a href="players/">По алфавиту</a></li>
# <li class="link"><a href="players/?rat">По рейтингу</a></li>
# </ul>
# <ul class="footer-menu">
# <li class="link">
# <a href="https://vk.com/ligapro" style="text-decoration: none;margin-left: -3px;vertical-align: text-bottom;" target="_blank">
# <img height="20" src="img/VK_BW_Compact_Logo.svg" width="20"/>
# </a>
# <a class="icon-youtube icon-social pr-2" href="https://www.youtube.com/channel/UC1kU19Np06WbBcoK2R6I4kg" style="text-decoration: none; font-size: 18px" target="_blank"></a>
# <!--a href="https://www.instagram.com/liga__pro/" target="_blank" style="text-decoration: none;margin-left: -3px;vertical-align: text-bottom;">
#           <img src="images/pixel-transparent.gif" height="16" width="16" style="background-image: url('img/insta16x16.png');">
#          </a-->
# </li>
# </ul>
# </div>
# <div class="col-12 col-md-6 col-lg-4 col-xl-3 mb-4 mb-md-0">
# <div>
# <ul class="footer-menu mb-2">
# <li class="title">Сейчас на сайте</li>
# <li>
# <div class="row">
# <div class="col-12">
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/8260" title="Иванов Владимир Игоревич">
# <img alt="Иванов Владимир Игоревич" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/2688" title="Ханевский Андрей Вадимович">
# <img alt="Ханевский Андрей Вадимович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/2688.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6515" title="Ковалев Алексей Иванович">
# <img alt="Ковалев Алексей Иванович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/1816" title="Шагаров Олег Евгеньевич">
# <img alt="Шагаров Олег Евгеньевич" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/1816.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6499" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/399" title="Конашков Илья Сергеевич">
# <img alt="Конашков Илья Сергеевич" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/399.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/8390" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6356" title="Carlos Francisco Coronado Astocaza Carlosf1262">
# <img alt="Carlos Francisco Coronado Astocaza Carlosf1262" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/6356.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/8409" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/8409.jpeg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6670" title="Дехтяренко Александр Васильевич">
# <img alt="Дехтяренко Александр Васильевич" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/6670.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/8028" title="Иванов Андрей Сергеевич">
# <img alt="Иванов Андрей Сергеевич" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/7581" title="Егоров Павел Евгеньевич">
# <img alt="Егоров Павел Евгеньевич" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/7581.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/7247" title="Доранов Иван Иванович">
# <img alt="Доранов Иван Иванович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6075" title="He Ya NN">
# <img alt="He Ya NN" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6504" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/8836" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/7988" title="Безнос Александр Алексеевич">
# <img alt="Безнос Александр Алексеевич" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/8661" title="Мареев Никита Геннадьевич">
# <img alt="Мареев Никита Геннадьевич" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/8661.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/7143" title="Володин Дмитрий Андреевич">
# <img alt="Володин Дмитрий Андреевич" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/7143.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/7146" title="Acar Bayram Acar">
# <img alt="Acar Bayram Acar" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/7754" title="Тужилин Александр Сергеевич">
# <img alt="Тужилин Александр Сергеевич" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/7754.jpeg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6486" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6480" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/8571" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/8806" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/1056" title="Балакин Дмитрий Александрович">
# <img alt="Балакин Дмитрий Александрович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/1056.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6058" title="Бутковский Юрий Борисович">
# <img alt="Бутковский Юрий Борисович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6127" title="Ковалев Игорь Анатольевич">
# <img alt="Ковалев Игорь Анатольевич" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/6127.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6410" title="Грандмен">
# <img alt="Грандмен" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/7949" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/2441" title="Тихненко Дмитрий Вячеславович">
# <img alt="Тихненко Дмитрий Вячеславович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/2441.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6494" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6131" title="Киселев Виталий Викторович">
# <img alt="Киселев Виталий Викторович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/8314" title="Амеличкин Игорь Вадимович">
# <img alt="Амеличкин Игорь Вадимович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6051" title="Петров Петр Петрович">
# <img alt="Петров Петр Петрович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/7000" title="Григорьев Валерий Станиславович">
# <img alt="Григорьев Валерий Станиславович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/7963" title="Zhurbabekov Herbert Ilyich">
# <img alt="Zhurbabekov Herbert Ilyich" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/181" title="Администратор">
# <img alt="Администратор" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/181.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/599" title="Козлов Александр Юрьевич">
# <img alt="Козлов Александр Юрьевич" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/599.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/5488" title="Модератор">
# <img alt="Модератор" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6488" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/7396" title="Резников Михаил Борисович">
# <img alt="Резников Михаил Борисович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/7396.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/7476" title="Богатов Дмитрий Алексеевич">
# <img alt="Богатов Дмитрий Алексеевич" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/7476.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/8877" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6390" title="Viljo Metsamaa Robertovich">
# <img alt="Viljo Metsamaa Robertovich" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6498" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6503" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/8885" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/1940" title="Писаренко Леонид Владимирович">
# <img alt="Писаренко Леонид Владимирович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/4806" title="Robert Poloski polskarobo">
# <img alt="Robert Poloski polskarobo" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6073" title="Руднев Игорь Викторович">
# <img alt="Руднев Игорь Викторович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6266" title="Викулин Андрей Владимирович">
# <img alt="Викулин Андрей Владимирович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6662" title="Кошель Владимир Леонидович">
# <img alt="Кошель Владимир Леонидович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/6662.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/8595" title="Скоблов Антон Александрович">
# <img alt="Скоблов Антон Александрович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/8595.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/154" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/5761" title="Агабабян Роберт Арменович">
# <img alt="Агабабян Роберт Арменович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('./upload/img/ru/players/5761.jpg');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6319" title="Смирнов Владимир Олегович">
# <img alt="Смирнов Владимир Олегович" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/6492" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/7324" title="Бугаков Игорь Сергеевич">
# <img alt="Бугаков Игорь Сергеевич" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/8746" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# <a class="userpic-xs d-inline-block mr-2 mb-2" href="players/8855" title="Noname">
# <img alt="Noname" class="player-bg-img rounded" height="30" src="images/pixel-transparent.gif" style="background-image: url('images/no_image_mini.png');"/>
# </a>
# </div>
# </div>
# </li>
# <li class="mt-2 clearfix text-uppercase">
# <div class="pr-3 small float-left">Всего: <span class="text-success">61 игрок</span> и <span class="text-white-50">12 гостей</span></div>
# <div class="small float-right"><a class="icon-arws text-success" href="players/">все игроки</a></div>
# </li>
# </ul>
# </div>
# <div class="mt-3">
# <ul class="footer-menu mb-2 text-uppercase">
# <li class="title">Статистика</li>
# <li>
# <div class="icon-arws inline"></div>
# <div class="inner inline small">Игроков в базе : <span class="pl-2"><a class="text-light" href="players/">8103</a></span></div>
# </li>
# <li>
# <div class="icon-arws inline"></div>
# <div class="inner inline small">Турниров : <span class="pl-2"><a class="text-light" href="tours/">31851</a></span></div>
# </li>
# <li>
# <div class="icon-arws inline"></div>
# <div class="inner inline small">Игр : <span class="pl-2">308185</span></div>
# </li>
# <li>
# <a class="icon-arws small text-success text-uppercase" href="statistics/">больше статистики</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-JYTDEKEFDJ"></script>
# <script>
#    window.dataLayer = window.dataLayer || [];
#    function gtag(){dataLayer.push(arguments);}
#    gtag('js', new Date());
#    gtag('config', 'G-JYTDEKEFDJ');
#   </script>
# <script crossorigin="anonymous" integrity="sha384-UO2eT0CpHqdSJQ6hJty5KVphtPhzWj9WO1clHTMGa3JDZwrnQq4sF86dIHNDz0W1" src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.7/umd/popper.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-JjSmVgyd0p3pXB1rRibZUAYoIIy6OrQ6VrjIEaFf/nJGzIxFDsf4x0xIM+B07jRM" src="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/js/bootstrap.min.js"></script>
# <script src="https://cdn.datatables.net/v/bs4/dt-1.10.22/b-1.6.4/b-html5-1.6.4/fc-3.3.1/kt-2.5.3/r-2.2.6/rg-1.1.2/rr-1.2.7/sc-2.0.3/sb-1.0.0/sp-1.2.0/sl-1.3.1/datatables.min.js" type="text/javascript"></script>
# <script src="js/handy-scroll.js" type="text/javascript"></script>
# </body>
# </html>
