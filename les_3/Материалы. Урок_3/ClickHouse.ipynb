# %%
# !pip install clickhouse_driver
# Out:
# Requirement already satisfied: clickhouse_driver in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (0.2.7)
# Requirement already satisfied: pytz in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from clickhouse_driver) (2022.7.1)
# Requirement already satisfied: tzlocal in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from clickhouse_driver) (5.2)
# Requirement already satisfied: tzdata in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from tzlocal->clickhouse_driver) (2024.1)

# %%
from clickhouse_driver import Client

# %%
client = Client(host = 'v56xfsiljq.eu-west-1.aws.clickhouse.cloud',
                user='default',
                secure = True, 
                port = 9440,
                password = 'z61ZLa!si:.I')

# %%
client.execute('SHOW TABLES')
# Out:
# Failed to connect to v56xfsiljq.eu-west-1.aws.clickhouse.cloud:9440
# Traceback (most recent call last):
#   File "c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\clickhouse_driver\connection.py", line 396, in connect
#     return self._init_connection(host, port)
#   File "c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\clickhouse_driver\connection.py", line 326, in _init_connection
#     self.socket = self._create_socket(host, port)
#   File "c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\clickhouse_driver\connection.py", line 276, in _create_socket
#     for res in socket.getaddrinfo(host, port, 0, socket.SOCK_STREAM):
#   File "c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\socket.py", line 955, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# socket.gaierror: [Errno 11001] getaddrinfo failed
# ---------------------------------------------------------------------------
# NetworkError                              Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 client.execute('SHOW TABLES')
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\clickhouse_driver\client.py:370, in Client.execute(self, query, params, with_column_types, external_tables, query_id, settings, types_check, columnar)
#     327 """
#     328 Executes query.
#     329
#    (...)
#     365               and types.
#     366 """
#     368 start_time = time()
# --> 370 with self.disconnect_on_error(query, settings):
#     371     # INSERT queries can use list/tuple/generator of list/tuples/dicts.
#     372     # For SELECT parameters can be passed in only in dict right now.
#     373     is_insert = isinstance(params, (list, tuple, types.GeneratorType))
#     375     if is_insert:
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\clickhouse_driver\client.py:314, in Client.disconnect_on_error(self, query, settings)
#     311 @contextmanager
#     312 def disconnect_on_error(self, query, settings):
#     313     try:
# --> 314         self.establish_connection(settings)
#     316         yield
#     318         self.track_current_database(query)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\clickhouse_driver\client.py:301, in Client.establish_connection(self, settings)
#     299     self.connection = self.get_connection()
#     300     self.make_query_settings(settings)
# --> 301     self.connection.force_connect()
#     302     self.last_query = QueryInfo()
#     304 except (errors.SocketTimeoutError, errors.NetworkError):
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\clickhouse_driver\connection.py:254, in Connection.force_connect(self)
#     251 self.check_query_execution()
#     253 if not self.connected:
# --> 254     self.connect()
#     256 elif not self.ping():
#     257     logger.warning('Connection was closed, reconnecting.')
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\clickhouse_driver\connection.py:417, in Connection.connect(self)
#     414     self.hosts.rotate(-1)
#     416 if err is not None:
# --> 417     raise err
#
# NetworkError: Code: 210. getaddrinfo failed (v56xfsiljq.eu-west-1.aws.clickhouse.cloud:9440)

# %%
client.execute('SHOW DATABASES')
# Out:
# Failed to connect to v56xfsiljq.eu-west-1.aws.clickhouse.cloud:9440
# Traceback (most recent call last):
#   File "c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\clickhouse_driver\connection.py", line 396, in connect
#     return self._init_connection(host, port)
#   File "c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\clickhouse_driver\connection.py", line 326, in _init_connection
#     self.socket = self._create_socket(host, port)
#   File "c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\clickhouse_driver\connection.py", line 276, in _create_socket
#     for res in socket.getaddrinfo(host, port, 0, socket.SOCK_STREAM):
#   File "c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\socket.py", line 955, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# socket.gaierror: [Errno 11001] getaddrinfo failed
# ---------------------------------------------------------------------------
# NetworkError                              Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 client.execute('SHOW DATABASES')
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\clickhouse_driver\client.py:370, in Client.execute(self, query, params, with_column_types, external_tables, query_id, settings, types_check, columnar)
#     327 """
#     328 Executes query.
#     329
#    (...)
#     365               and types.
#     366 """
#     368 start_time = time()
# --> 370 with self.disconnect_on_error(query, settings):
#     371     # INSERT queries can use list/tuple/generator of list/tuples/dicts.
#     372     # For SELECT parameters can be passed in only in dict right now.
#     373     is_insert = isinstance(params, (list, tuple, types.GeneratorType))
#     375     if is_insert:
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\clickhouse_driver\client.py:314, in Client.disconnect_on_error(self, query, settings)
#     311 @contextmanager
#     312 def disconnect_on_error(self, query, settings):
#     313     try:
# --> 314         self.establish_connection(settings)
#     316         yield
#     318         self.track_current_database(query)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\clickhouse_driver\client.py:301, in Client.establish_connection(self, settings)
#     299     self.connection = self.get_connection()
#     300     self.make_query_settings(settings)
# --> 301     self.connection.force_connect()
#     302     self.last_query = QueryInfo()
#     304 except (errors.SocketTimeoutError, errors.NetworkError):
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\clickhouse_driver\connection.py:254, in Connection.force_connect(self)
#     251 self.check_query_execution()
#     253 if not self.connected:
# --> 254     self.connect()
#     256 elif not self.ping():
#     257     logger.warning('Connection was closed, reconnecting.')
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\clickhouse_driver\connection.py:417, in Connection.connect(self)
#     414     self.hosts.rotate(-1)
#     416 if err is not None:
# --> 417     raise err
#
# NetworkError: Code: 210. getaddrinfo failed (v56xfsiljq.eu-west-1.aws.clickhouse.cloud:9440)

# %%
client.execute('DROP TABLE trips')

# %%
client.execute (
'''
CREATE TABLE trips
(
    `trip_id` UInt32,
    `vendor_id` Enum8('1' = 1, '2' = 2, '3' = 3, '4' = 4, 'CMT' = 5, 'VTS' = 6, 'DDS' = 7, 'B02512' = 10, 'B02598' = 11, 'B02617' = 12, 'B02682' = 13, 'B02764' = 14, '' = 15),
    `pickup_date` Date,
    `pickup_datetime` DateTime,
    `dropoff_date` Date,
    `dropoff_datetime` DateTime,
    `store_and_fwd_flag` UInt8,
    `rate_code_id` UInt8,
    `pickup_longitude` Float64,
    `pickup_latitude` Float64,
    `dropoff_longitude` Float64,
    `dropoff_latitude` Float64,
    `passenger_count` UInt8,
    `trip_distance` Float64,
    `fare_amount` Float32,
    `extra` Float32,
    `mta_tax` Float32,
    `tip_amount` Float32,
    `tolls_amount` Float32,
    `ehail_fee` Float32,
    `improvement_surcharge` Float32,
    `total_amount` Float32,
    `payment_type` Enum8('UNK' = 0, 'CSH' = 1, 'CRE' = 2, 'NOC' = 3, 'DIS' = 4),
    `trip_type` UInt8,
    `pickup` FixedString(25),
    `dropoff` FixedString(25),
    `cab_type` Enum8('yellow' = 1, 'green' = 2, 'uber' = 3),
    `pickup_nyct2010_gid` Int8,
    `pickup_ctlabel` Float32,
    `pickup_borocode` Int8,
    `pickup_ct2010` String,
    `pickup_boroct2010` String,
    `pickup_cdeligibil` String,
    `pickup_ntacode` FixedString(4),
    `pickup_ntaname` String,
    `pickup_puma` UInt16,
    `dropoff_nyct2010_gid` UInt8,
    `dropoff_ctlabel` Float32,
    `dropoff_borocode` UInt8,
    `dropoff_ct2010` String,
    `dropoff_boroct2010` String,
    `dropoff_cdeligibil` String,
    `dropoff_ntacode` FixedString(4),
    `dropoff_ntaname` String,
    `dropoff_puma` UInt16
)
ENGINE = MergeTree
PARTITION BY toYYYYMM(pickup_date)
ORDER BY pickup_datetime;
'''
)
# Out:
# []

# %%
client.execute(
'''
INSERT INTO trips
SELECT * FROM s3(
    'https://datasets-documentation.s3.eu-west-3.amazonaws.com/nyc-taxi/trips_{1..2}.gz',
    'TabSeparatedWithNames', "
    `trip_id` UInt32,
    `vendor_id` Enum8('1' = 1, '2' = 2, '3' = 3, '4' = 4, 'CMT' = 5, 'VTS' = 6, 'DDS' = 7, 'B02512' = 10, 'B02598' = 11, 'B02617' = 12, 'B02682' = 13, 'B02764' = 14, '' = 15),
    `pickup_date` Date,
    `pickup_datetime` DateTime,
    `dropoff_date` Date,
    `dropoff_datetime` DateTime,
    `store_and_fwd_flag` UInt8,
    `rate_code_id` UInt8,
    `pickup_longitude` Float64,
    `pickup_latitude` Float64,
    `dropoff_longitude` Float64,
    `dropoff_latitude` Float64,
    `passenger_count` UInt8,
    `trip_distance` Float64,
    `fare_amount` Float32,
    `extra` Float32,
    `mta_tax` Float32,
    `tip_amount` Float32,
    `tolls_amount` Float32,
    `ehail_fee` Float32,
    `improvement_surcharge` Float32,
    `total_amount` Float32,
    `payment_type` Enum8('UNK' = 0, 'CSH' = 1, 'CRE' = 2, 'NOC' = 3, 'DIS' = 4),
    `trip_type` UInt8,
    `pickup` FixedString(25),
    `dropoff` FixedString(25),
    `cab_type` Enum8('yellow' = 1, 'green' = 2, 'uber' = 3),
    `pickup_nyct2010_gid` Int8,
    `pickup_ctlabel` Float32,
    `pickup_borocode` Int8,
    `pickup_ct2010` String,
    `pickup_boroct2010` String,
    `pickup_cdeligibil` String,
    `pickup_ntacode` FixedString(4),
    `pickup_ntaname` String,
    `pickup_puma` UInt16,
    `dropoff_nyct2010_gid` UInt8,
    `dropoff_ctlabel` Float32,
    `dropoff_borocode` UInt8,
    `dropoff_ct2010` String,
    `dropoff_boroct2010` String,
    `dropoff_cdeligibil` String,
    `dropoff_ntacode` FixedString(4),
    `dropoff_ntaname` String,
    `dropoff_puma` UInt16
") SETTINGS input_format_try_infer_datetimes = 0
'''
)
# Out:
# []

# %%
client.execute("SELECT count() FROM trips")
# Out:
# [(1999657,)]

# %%
tip_amount = client.execute("SELECT round(avg(tip_amount), 2) FROM trips")  
print(tip_amount)
# Out:
# [(1.68,)]

# %%
type(tip_amount)
# Out:
# list

# %%
tip_amount[0][0]
# Out:
# 1.68

# %%
avg_price = client.execute(
'''
SELECT
    passenger_count,
    ceil(avg(total_amount),2) AS average_total_amount
FROM trips
GROUP BY passenger_count
'''
)

# %%
import pandas as pd

# %%
df = pd.DataFrame(avg_price, columns=("passenger_count", "average_total_amount"))

# %%
df
# Out:
#    passenger_count  average_total_amount
# 0                0                 22.69
# 1                1                 15.97
# 2                2                 17.15
# 3                3                 16.76
# 4                4                 17.33
# 5                5                 16.35
# 6                6                 16.04
# 7                7                 59.80
# 8                8                 36.41
# 9                9                  9.81

# %%
pickup_num = client.execute(
'''
SELECT
    pickup_date,
    pickup_ntaname,
    SUM(1) AS number_of_trips
FROM trips
GROUP BY pickup_date, pickup_ntaname
ORDER BY pickup_date ASC
'''
)

# %%
df = pd.DataFrame(pickup_num, columns=("pickup_date", "pickup_ntaname", "number_of_trips"))
df
# Out:
#      pickup_date                    pickup_ntaname  number_of_trips
# 0     2015-07-01      Brooklyn Heights-Cobble Hill               13
# 1     2015-07-01                       Old Astoria                5
# 2     2015-07-01                          Flushing                1
# 3     2015-07-01                         Yorkville              378
# 4     2015-07-01                          Gramercy              344
# ...          ...                               ...              ...
# 8746  2015-09-30                            Hollis                1
# 8747  2015-09-30                Claremont-Bathgate                1
# 8748  2015-09-30           Turtle Bay-East Midtown             1060
# 8749  2015-09-30  East New York (Pennsylvania Ave)                1
# 8750  2015-09-30                   Windsor Terrace                1
#
# [8751 rows x 3 columns]

# %%
trip_minutes = client.execute(
'''
SELECT
    avg(tip_amount) AS avg_tip,
    avg(fare_amount) AS avg_fare,
    avg(passenger_count) AS avg_passenger,
    count() AS count,
    truncate(date_diff('second', pickup_datetime, dropoff_datetime)/3600) as trip_minutes
FROM trips
WHERE trip_minutes > 0
GROUP BY trip_minutes
ORDER BY trip_minutes DESC
'''
)

# %%
df = pd.DataFrame(trip_minutes, columns=("avg_tip", "avg_fare", "avg_passenger", "count", "trip_minutes"))
df
# Out:
#      avg_tip   avg_fare  avg_passenger  count  trip_minutes
# 0   0.980000  10.000000       1.500000      2         458.0
# 1   1.182368  14.493378       2.060201   1495          23.0
# 2   2.115957  23.228723       2.468085     47          22.0
# 3   1.121818  13.681818       1.909091     11          21.0
# 4   0.321818  18.045455       2.363636     11          20.0
# 5   2.149000  17.550000       1.500000     10          19.0
# 6   4.537059  37.000000       1.764706     17          18.0
# 7   1.425000  30.388462       1.423077     26          17.0
# 8   1.770500  20.050000       2.200000     20          16.0
# 9   1.490870  22.782609       2.130435     23          15.0
# 10  1.441579  23.210000       2.315789     19          14.0
# 11  7.708461  27.576923       1.769231     13          13.0
# 12  2.814444  23.072222       1.944444     18          12.0
# 13  2.031333  17.733333       1.933333     15          11.0
# 14  1.736000  22.275000       2.300000     20          10.0
# 15  1.960556  32.486111       2.305556     36           9.0
# 16  1.963478  25.608696       1.913043     23           8.0
# 17  2.581250  26.041667       1.583333     24           7.0
# 18  1.550645  22.838710       2.225806     31           6.0
# 19  1.668125  43.468750       2.250000     32           5.0
# 20  0.589516  19.252581       0.645161     62           4.0
# 21  1.077632  44.263158       1.763158     38           3.0
# 22  5.287600  61.835500       1.875000    200           2.0
# 23  6.039334  54.977343       1.811057  11739           1.0
